# %% [markdown]
# ## Script para download de dados históricos de cripyto moedas.

# %%
from datetime import datetime, timedelta
import os
import requests
import time

# %%
def write_data_url( response, file_name, path_dir ):
    with open( f"{path_dir}/{file_name}", "wb" ) as file:
        file.write( response.content )
    return

# %%
def get_data_url( pair, interval, time_range ):
    now = datetime.now()
    date = now
    
    while now.year - date.year < time_range :
        year = str( date.year )
        month = date.month
        
        if month >= 10 and month <= 12:
            month = str( date.month )
        else:
            month = "0" + str( date.month )
            
        file_name = f"{pair}-{interval}-{year}-{month}.zip"
        path_dir = f"{pair}-{interval}"
        
        if not os.path.exists( path_dir ):
            os.mkdir( path_dir )
            
        data_url = f"https://data.binance.vision/data/spot/monthly/klines/{pair}/{interval}/{file_name}"
        try:
            response = requests.get( data_url )
            if response.status_code == 200:
                print( f"Download do arquivo {file_name} executado com sucesso!" )
        except:
            if response.status_code != 200:
                while response.status_code != 200:
                    print( f"Erro ao baixar arquivo {file_name}")
                    print( f"Tentando reconectar em 10 segundos" )
                    time.sleep( 10 )
                    response = requests.get( data_url )
                    if response.status_code == 200:
                        break
                    
            
        write_data_url( response, file_name, path_dir )
        date = date - timedelta( days = 30 )
    
    return

# %%
usdt_pairs = [ 'BTCUSDT',  'ETHUSDT',  'XMRUSDT',  'XRPUSDT',   'BUSDUSDT',
               'DOGEUSDT', 'LTCUSDT',  'ETCUSDT',  'ZECUSDT',   'MANAUSDT' ]

api_intervals = [ "1m", "5m", "2h", "1d" ]

for pair in usdt_pairs:
    for interval in api_intervals:
        
        if interval == "1m":
            time_range = 1
            
        if interval == "5m":
            time_range = 2
        
        if interval == "2h":
            time_range = 3
            
        if interval == "1d":
            time_range = 5
                     
        get_data_url( pair, interval, time_range )
# Out:
# Download do arquivo BTCUSDT-1m-2022-11.zip executado com sucesso!
# Download do arquivo BTCUSDT-1m-2022-10.zip executado com sucesso!
# Download do arquivo BTCUSDT-1m-2022-09.zip executado com sucesso!
# Download do arquivo BTCUSDT-1m-2022-08.zip executado com sucesso!
# Download do arquivo BTCUSDT-1m-2022-07.zip executado com sucesso!
# Download do arquivo BTCUSDT-1m-2022-06.zip executado com sucesso!
# Download do arquivo BTCUSDT-1m-2022-05.zip executado com sucesso!
# Download do arquivo BTCUSDT-1m-2022-04.zip executado com sucesso!
# Download do arquivo BTCUSDT-1m-2022-03.zip executado com sucesso!
# Download do arquivo BTCUSDT-1m-2022-02.zip executado com sucesso!
# Download do arquivo BTCUSDT-1m-2022-01.zip executado com sucesso!
# Download do arquivo BTCUSDT-5m-2022-11.zip executado com sucesso!
# Download do arquivo BTCUSDT-5m-2022-10.zip executado com sucesso!
# Download do arquivo BTCUSDT-5m-2022-09.zip executado com sucesso!
# ...

# %%
pari = "test"
interval = "22"
os.mkdir( f"{pair} - {interval}" )

# %%
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1d/BTCUSDT-1d-2022-11.zip'
# Out:
# --2022-12-10 02:00:21--  https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1d/BTCUSDT-1d-2022-11.zip
# Resolving data.binance.vision (data.binance.vision)... 108.139.182.77, 108.139.182.16, 108.139.182.95, ...
# Connecting to data.binance.vision (data.binance.vision)|108.139.182.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2191 (2,1K) [application/zip]
# Saving to: ‘BTCUSDT-1d-2022-11.zip.8’
#
# BTCUSDT-1d-2022-11. 100%[===================>]   2,14K  --.-KB/s    in 0s
#
# 2022-12-10 02:00:22 (430 MB/s) - ‘BTCUSDT-1d-2022-11.zip.8’ saved [2191/2191]
#
# /home/eliel/Downloads/cripyto_data/BTCUSDT-1d/BTCUSDT-1d-2022-11.zip: Scheme missing.
# FINISHED --2022-12-10 02:00:22--
# Total wall clock time: 1,4s
# Downloaded: 1 files, 2,1K in 0s (430 MB/s)

# %%
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1d/BMANAUSDT-1d-2020-03.zip'
# Out:
# --2022-12-10 23:53:32--  https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1d/BMANAUSDT-1d-2020-03.zip
# Resolving data.binance.vision (data.binance.vision)... 13.227.126.45, 13.227.126.108, 13.227.126.80, ...
# Connecting to data.binance.vision (data.binance.vision)|13.227.126.45|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2022-12-10 23:53:35 ERROR 404: Not Found.

# %%
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-12.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-11.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-10.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-09.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-08.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-07.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-06.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-05.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-04.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-03.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-02.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-01.zip'
# Out:
# --2022-12-10 02:11:41--  https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-12.zip
# Resolving data.binance.vision (data.binance.vision)... 108.139.182.95, 108.139.182.16, 108.139.182.79, ...
# Connecting to data.binance.vision (data.binance.vision)|108.139.182.95|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2022-12-10 02:11:42 ERROR 404: Not Found.
#
# --2022-12-10 02:11:42--  https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/1m/BTCUSDT-1m-2022-11.zip
# Resolving data.binance.vision (data.binance.vision)... 108.139.182.77, 108.139.182.79, 108.139.182.95, ...
# Connecting to data.binance.vision (data.binance.vision)|108.139.182.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2241831 (2,1M) [application/zip]
# Saving to: ‘BTCUSDT-1m-2022-11.zip’
#
# BTCUSDT-1m-2022-11. 100%[===================>]   2,14M  1001KB/s    in 2,2s
#
# ...

# %%
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2022-12.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2022-11.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2022-10.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2022-09.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2022-08.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2022-07.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2022-06.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2022-05.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2022-04.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2022-03.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2022-02.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2022-01.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2021-12.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2021-11.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2021-10.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2021-09.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2021-08.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2021-07.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2021-06.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2021-05.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2021-04.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2021-03.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2021-02.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2021-01.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2020-12.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2020-11.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2020-10.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2020-09.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2020-08.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2020-07.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2020-06.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2020-05.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2020-04.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2020-03.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2020-02.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2020-01.zip'
# Out:
# --2022-12-10 02:12:52--  https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2022-12.zip
# Resolving data.binance.vision (data.binance.vision)... 108.139.182.79, 108.139.182.16, 108.139.182.77, ...
# Connecting to data.binance.vision (data.binance.vision)|108.139.182.79|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2022-12-10 02:12:54 ERROR 404: Not Found.
#
# --2022-12-10 02:12:54--  https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/2h/BTCUSDT-2h-2022-11.zip
# Resolving data.binance.vision (data.binance.vision)... 108.139.182.95, 108.139.182.16, 108.139.182.79, ...
# Connecting to data.binance.vision (data.binance.vision)|108.139.182.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22522 (22K) [application/zip]
# Saving to: ‘BTCUSDT-2h-2022-11.zip’
#
# BTCUSDT-2h-2022-11. 100%[===================>]  21,99K  --.-KB/s    in 0,09s
#
# ...

# %%
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2022-12.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2022-11.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2022-10.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2022-09.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2022-08.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2022-07.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2022-06.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2022-05.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2022-04.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2022-03.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2022-02.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2022-01.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2021-12.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2021-11.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2021-10.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2021-09.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2021-08.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2021-07.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2021-06.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2021-05.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2021-04.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2021-03.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2021-02.zip'
! wget 'https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2021-01.zip'
# Out:
# --2022-12-10 02:13:51--  https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2022-12.zip
# Resolving data.binance.vision (data.binance.vision)... 52.84.83.117, 52.84.83.75, 52.84.83.115, ...
# Connecting to data.binance.vision (data.binance.vision)|52.84.83.117|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2022-12-10 02:13:52 ERROR 404: Not Found.
#
# --2022-12-10 02:13:52--  https://data.binance.vision/data/spot/monthly/klines/BTCUSDT/5m/BTCUSDT-5m-2022-11.zip
# Resolving data.binance.vision (data.binance.vision)... 52.84.83.75, 52.84.83.115, 52.84.83.117, ...
# Connecting to data.binance.vision (data.binance.vision)|52.84.83.75|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 472167 (461K) [application/zip]
# Saving to: ‘BTCUSDT-5m-2022-11.zip’
#
# BTCUSDT-5m-2022-11. 100%[===================>] 461,10K   388KB/s    in 1,2s
#
# ...
